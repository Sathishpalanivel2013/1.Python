# %%
#print Statement
print("HOPE AI")
# Out:
# HOPE AI

# %%
# Buy input
name = input("Enter your institute name? :")
# Out:
# Enter your institute name? : HOPE AI

# %%
#Buy inputs
name1 = input("Enter your name:")
age = int(input("Enter your age:"))
schoolname = input("Enter your school name:")
degree = input("Enter your degree:")
# Out:
# Enter your name: Raj
# Enter your age: 15
# Enter your school name: Guru school
# Enter your degree: B.E CSE

# %%
#Addition
a=43
b=34
add=a+b
print(f"a={a}")
print(f"b={b}")
print(f"add={add}")
# Out:
# a=43
# b=34
# add=77

# %%
#Subtraction
a=43
b=34
sub=a-b
print(f"a={a}")
print(f"b={b}")
print(f"sub={sub}")
# Out:
# a=43
# b=34
# sub=9

# %%
#Multiplication
a=63
b=97
Mul = a * b
print(f"a={a}")
print(f"b={b}")
print(f"mul={Mul}")
# Out:
# a=63
# b=97
# mul=6111

# %%
#Division
a=76
b=31
FD = 76 / 31
print(f"a={a}")
print(f"b={b}")
print(f"Float Div = {FD}")
# Out:
# a=76
# b=31
# Float Div = 2.4516129032258065

# %%
#Floor division
a=76
b=31
FLD = 76 // 31
print(f"a={a}")
print(f"b={b}")
print(f"Floor Div = {FLD}")
# Out:
# a=76
# b=31
# Floor Div = 2

# %%
#Modulo
a = 76
b = 31
MOD = 76 % 31
print(f"a={a}")
print(f"b={b}")
print(f"Modulo = {MOD}")
# Out:
# a=76
# b=31
# Modulo = 14

# %%
#Power
a=4
b=4
POW = 4 ** 4
print(f"a={a}")
print(f"b={b}")
print(f"Power = {POW}")
# Out:
# a=4
# b=4
# Power = 256
