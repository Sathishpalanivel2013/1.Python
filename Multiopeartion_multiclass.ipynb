# %%
from Multioperation_multiclass import subfields,oddoreven,eligible,percentage,triangle

# %%
subfields.Subfields()
# Out:
# Sub-Fields in AI are:
# Machine learning
# Neural Networks
# Vision
# Robotics
# Speech processing
# Natural language processing

# %%
oddoreven.oddeven()
# Out:
# Enter a number 3
# 3 is odd number

# %%
eligible.eligible()
# Out:
# Your Gender: male
# Your age 32
# Eligiable

# %%
percentage.percentage()
# Out:
# Subject1 =  92
# Subject2 =  94
# Subject3 =  87
# Subject4 =  77
# Subject5 =  94
# Total = 444
# percentage = 88.8

# %%
triangle.triangle()
# Out:
# Height =  32
# breadth =  34
# Area formula: ( height * breadth )/2
# Area of triangle:544.0
# Height1 =  2
# Height2 =  4
# Breadth =  4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle:10
