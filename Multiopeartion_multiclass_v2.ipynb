# %%
from Multioperation2 import Multioperation

# %%
Multioperation.subfields()
# Out:
# Enter number 1 for List Area of AI subfields 1
# Sub-Fields in AI area:
#  Machine learning
#  Neural networks
#  Vision
#  Robotics
#  Speach processing
#  Natural language processing

# %%
Multioperation.oddeven()
# Out:
# Enter a number 7
# 7 is odd number

# %%
Multioperation.eligible()
# Out:
# Your Gender: male
# Your age 54
# Eligiable

# %%
Multioperation.percentage()
# Out:
# Subject1 =  91
# Subject2 =  94
# Subject3 =  96
# Subject4 =  92
# Subject5 =  97
# Total = 470
# percentage = 94.0

# %%
Multioperation.triangle()
# Out:
# Height =  34
# breadth =  35
# Area formula: ( height * breadth )/2
# Area of triangle:595.0
# Height1 =  4
# Height2 =  5
# Breadth =  6
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle:15
